# %%
import pandas as pd
import numpy as np
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Language Detection.csv")
df
# Out:
#                                                     Text Language
# 0       Nature, in the broadest sense, is the natural...  English
# 1      "Nature" can refer to the phenomena of the phy...  English
# 2      The study of nature is a large, if not the onl...  English
# 3      Although humans are part of nature, human acti...  English
# 4      [1] The word nature is borrowed from the Old F...  English
# ...                                                  ...      ...
# 10332  ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...  Kannada
# 10333  ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...  Kannada
# 10334  ಹೇಗೆ ' ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎ...  Kannada
# 10335  ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...  Kannada
# 10336  ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...  Kannada
#
# [10337 rows x 2 columns]

# %%
plt.figure(figsize=[20,30])
sns.countplot(x='Language',data=df)
plt.show()

# %%
df['Language'].unique()
# Out:
# array(['English', 'Malayalam', 'Hindi', 'Tamil', 'Portugeese', 'French',
#        'Dutch', 'Spanish', 'Greek', 'Russian', 'Danish', 'Italian',
#        'Turkish', 'Sweedish', 'Arabic', 'German', 'Kannada'], dtype=object)

# %%
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\a21ma\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
text = " ".join(df[df["Language"] == 'English']["Text"])
wordcloud = WordCloud(width=800,height=400, background_color = 'white', stopwords = set(stopwords.words('english'))).generate(text)

# %%
plt.figure(figsize=[10,5])
plt.imshow(wordcloud,interpolation = 'bilinear') #interpolation bilinear means smoother experience when resizing image
plt.title("Word Cloud for English Language")
plt.axis("off")
plt.show()

# %%
# Bar chart for top N words in each language
top_n = 10
text = " ".join(df[df['Language'] == 'English']['Text'])
text = text.lower()
words = text.split()
words = [word for word in words if word not in set(stopwords.words('english'))]
word_freq = nltk.FreqDist(words)
common_words = word_freq.most_common(top_n)
x_values, y_values = zip(*common_words)
plt.figure(figsize=(10, 5))

plt.bar(x_values, y_values)
plt.title(f"Top {top_n} Words in English Language")
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
df.shape
# Out:
# (10337, 2)

# %%
df.isna().sum()
# Out:
# Text        0
# Language    0
# dtype: int64

# %%
df['Language'].value_counts()
# Out:
# Language
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: count, dtype: int64

# %%
x=np.array(df['Text'])
y=np.array(df['Language'])

cv=CountVectorizer(lowercase=True)
X=cv.fit_transform(x)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=41)

# %%
#Visualizing the CountVectorizer
print(X.toarray()[0])
fn = cv.get_feature_names_out()
print(fn)
# Out:
# [0 0 0 ... 0 0 0]
# ['00' '000' '000க' ... 'ൾക' 'ൾപ' 'ൾമ']

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train,y_train)
dt.score(X_test,y_test)
# Out:
# 0.8704061895551257

# %%
from sklearn import tree
text_representation = tree.export_text(dt)
print(text_representation)
# Out:
# |--- feature_24867 <= 0.50
# |   |--- feature_6978 <= 0.50
# |   |   |--- feature_38187 <= 0.50
# |   |   |   |--- feature_6385 <= 0.50
# |   |   |   |   |--- feature_39159 <= 0.50
# |   |   |   |   |   |--- feature_17593 <= 0.50
# |   |   |   |   |   |   |--- feature_36665 <= 0.50
# |   |   |   |   |   |   |   |--- feature_1603 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_29447 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_12092 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12515 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 699
# |   |   |   |   |   |   |   |   |   |   |--- feature_12515 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: German
# |   |   |   |   |   |   |   |   |   |--- feature_12092 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Dutch
# |   |   |   |   |   |   |   |   |--- feature_29447 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Greek
# |   |   |   |   |   |   |   |--- feature_1603 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_14596 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_19706 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_33483 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: English
# |   |   |   |   |   |   |   |   |   |   |--- feature_33483 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Russian
# |   |   |   |   |   |   |   |   |   |--- feature_19706 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Danish
# |   |   |   |   |   |   |   |   |--- feature_14596 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4957 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Italian
# |   |   |   |   |   |   |   |   |   |--- feature_4957 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: French
# |   |   |   |   |   |   |--- feature_36665 >  0.50
# |   |   |   |   |   |   |   |--- class: Arabic
# |   |   |   |   |   |--- feature_17593 >  0.50
# |   |   |   |   |   |   |--- class: Sweedish
# |   |   |   |   |--- feature_39159 >  0.50
# |   |   |   |   |   |--- class: Malayalam
# |   |   |   |--- feature_6385 >  0.50
# |   |   |   |   |--- feature_8302 <= 0.50
# |   |   |   |   |   |--- feature_8391 <= 0.50
# |   |   |   |   |   |   |--- feature_9194 <= 0.50
# |   |   |   |   |   |   |   |--- feature_26222 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_14769 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_14596 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_17593 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 54
# |   |   |   |   |   |   |   |   |   |   |--- feature_17593 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Sweedish
# |   |   |   |   |   |   |   |   |   |--- feature_14596 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_19272 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_19272 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Spanish
# |   |   |   |   |   |   |   |   |--- feature_14769 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_15206 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_25723 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: French
# |   |   |   |   |   |   |   |   |   |   |--- feature_25723 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Portugeese
# |   |   |   |   |   |   |   |   |   |--- feature_15206 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Spanish
# |   |   |   |   |   |   |   |--- feature_26222 >  0.50
# |   |   |   |   |   |   |   |   |--- class: Dutch
# |   |   |   |   |   |   |--- feature_9194 >  0.50
# |   |   |   |   |   |   |   |--- feature_6868 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_27630 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: French
# |   |   |   |   |   |   |   |   |--- feature_27630 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Spanish
# |   |   |   |   |   |   |   |--- feature_6868 >  0.50
# |   |   |   |   |   |   |   |   |--- class: Danish
# |   |   |   |   |   |--- feature_8391 >  0.50
# |   |   |   |   |   |   |--- class: Portugeese
# |   |   |   |   |--- feature_8302 >  0.50
# |   |   |   |   |   |--- feature_16248 <= 0.50
# |   |   |   |   |   |   |--- class: Spanish
# |   |   |   |   |   |--- feature_16248 >  0.50
# |   |   |   |   |   |   |--- class: Portugeese
# |   |   |--- feature_38187 >  0.50
# |   |   |   |--- class: Tamil
# |   |--- feature_6978 >  0.50
# |   |   |--- class: Italian
# |--- feature_24867 >  0.50
# |   |--- feature_6385 <= 0.50
# |   |   |--- feature_15883 <= 0.50
# |   |   |   |--- feature_31639 <= 0.50
# |   |   |   |   |--- feature_6978 <= 1.50
# |   |   |   |   |   |--- feature_20391 <= 0.50
# |   |   |   |   |   |   |--- feature_34186 <= 0.50
# |   |   |   |   |   |   |   |--- feature_15297 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_37658 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_19151 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_29113 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: English
# |   |   |   |   |   |   |   |   |   |   |--- feature_29113 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Greek
# |   |   |   |   |   |   |   |   |   |--- feature_19151 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Portugeese
# |   |   |   |   |   |   |   |   |--- feature_37658 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Hindi
# |   |   |   |   |   |   |   |--- feature_15297 >  0.50
# |   |   |   |   |   |   |   |   |--- class: Malayalam
# |   |   |   |   |   |   |--- feature_34186 >  0.50
# |   |   |   |   |   |   |   |--- class: Arabic
# |   |   |   |   |   |--- feature_20391 >  0.50
# |   |   |   |   |   |   |--- class: Italian
# |   |   |   |   |--- feature_6978 >  1.50
# |   |   |   |   |   |--- class: Italian
# |   |   |   |--- feature_31639 >  0.50
# |   |   |   |   |--- class: Russian
# |   |   |--- feature_15883 >  0.50
# |   |   |   |--- class: Sweedish
# |   |--- feature_6385 >  0.50
# |   |   |--- feature_8391 <= 0.50
# |   |   |   |--- feature_8302 <= 0.50
# |   |   |   |   |--- feature_14769 <= 0.50
# |   |   |   |   |   |--- feature_27418 <= 0.50
# |   |   |   |   |   |   |--- feature_23739 <= 0.50
# |   |   |   |   |   |   |   |--- class: Sweedish
# |   |   |   |   |   |   |--- feature_23739 >  0.50
# |   |   |   |   |   |   |   |--- class: Portugeese
# |   |   |   |   |   |--- feature_27418 >  0.50
# |   |   |   |   |   |   |--- class: Dutch
# |   |   |   |   |--- feature_14769 >  0.50
# |   |   |   |   |   |--- class: French
# |   |   |   |--- feature_8302 >  0.50
# |   |   |   |   |--- class: Spanish
# |   |   |--- feature_8391 >  0.50
# |   |   |   |--- class: Portugeese

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=fn,
                   class_names=df['Language'].unique(),
                   filled=True,
                   max_depth=3) #increase max depth to see a more detailed version
# Out:
# c:\Users\a21ma\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_export.py:676: UserWarning: Glyph 2965 (\N{TAMIL LETTER KA}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\a21ma\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_export.py:676: UserWarning: Matplotlib currently does not support Tamil natively.
#   ann.update_bbox_position_size(renderer)
# c:\Users\a21ma\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\tree\_export.py:676: UserWarning: Glyph 2995 (\N{TAMIL LETTER LLA}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 2965 (\N{TAMIL LETTER KA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Matplotlib currently does not support Tamil natively.
#   func(*args, **kwargs)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 2995 (\N{TAMIL LETTER LLA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2965 (\N{TAMIL LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Matplotlib currently does not support Tamil natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\a21ma\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 2995 (\N{TAMIL LETTER LLA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
model=MultinomialNB(alpha=0.05)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.9859767891682786

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       1.00      0.96      0.98       107
#       Danish       1.00      0.97      0.99        75
#        Dutch       0.99      1.00      0.99        98
#      English       0.98      1.00      0.99       283
#       French       1.00      0.99      1.00       214
#       German       1.00      0.97      0.99       102
#        Greek       1.00      1.00      1.00        74
#        Hindi       1.00      0.92      0.96        13
#      Italian       0.99      0.99      0.99       137
#      Kannada       0.92      0.96      0.94        76
#    Malayalam       0.90      1.00      0.95       104
#   Portugeese       0.99      1.00      0.99       135
#      Russian       1.00      0.99      1.00       147
#      Spanish       1.00      0.99      0.99       184
#     Sweedish       0.99      0.98      0.98       127
#        Tamil       1.00      1.00      1.00        90
#      Turkish       1.00      0.94      0.97       102
#
#     accuracy                           0.99      2068
#    macro avg       0.99      0.98      0.98      2068
# weighted avg       0.99      0.99      0.99      2068

# %%
cf = confusion_matrix(y_test,pred)
plt.figure(figsize=(20,10))
unique_labels = df['Language'].unique()
sns.heatmap(cf,annot=True,fmt='g',cmap='coolwarm', xticklabels=unique_labels, yticklabels=unique_labels)
plt.show()

# %%
user=input("Enter sentence: ")
ans=np.array([user])
enc_ans=cv.transform(ans)
output=model.predict(enc_ans)
print('The detected language is: ',output[0])
# Out:
# The detected language is:  French

# %%
import numpy as np
from sklearn.pipeline import Pipeline

# Define the pipeline
pipeline = Pipeline([
    ('vectorizer', cv),
    ('classifier', model)
])

user_input = input("Enter sentence: ")

predicted_language = pipeline.predict([user_input])[0]

print('The detected language is:', predicted_language)
# Out:
# The detected language is: English
